# %%
# %pip install netcdf4 pydap

# %%
import pandas as pd
from pathlib import Path

arquivo = Path("/content/Tuinenberg-etal_2020.tab")

# descobrir onde o meta-header termina
with arquivo.open(encoding="utf-8") as f:
    for i, linha in enumerate(f):
        if linha.strip() == "*/":          # última linha do header
            skip = i + 1                  # primeira linha de dados
            break

df = pd.read_csv(arquivo,
                 sep="\t",                # delimitador
                 skiprows=skip,           # pula o header
                 comment="#",             # ignora possíveis linhas iniciadas com #
                 na_values=["nan", "NaN"])  # trata ausentes

df
# Out:
#                                Content                  File name File format  \
# 0     January, 0.5° spatial resolution  utrack_climatology_0.5_01      netCDF
# 1    February, 0.5° spatial resolution  utrack_climatology_0.5_02      netCDF
# 2       March, 0.5° spatial resolution  utrack_climatology_0.5_03      netCDF
# 3       April, 0.5° spatial resolution  utrack_climatology_0.5_04      netCDF
# 4         May, 0.5° spatial resolution  utrack_climatology_0.5_05      netCDF
# 5        June, 0.5° spatial resolution  utrack_climatology_0.5_06      netCDF
# 6        July, 0.5° spatial resolution  utrack_climatology_0.5_07      netCDF
# 7      August, 0.5° spatial resolution  utrack_climatology_0.5_08      netCDF
# 8   September, 0.5° spatial resolution  utrack_climatology_0.5_09      netCDF
# 9     October, 0.5° spatial resolution  utrack_climatology_0.5_10      netCDF
# 10   November, 0.5° spatial resolution  utrack_climatology_0.5_11      netCDF
# 11   December, 0.5° spatial resolution  utrack_climatology_0.5_12      netCDF
# 12      January, 1° spatial resolution  utrack_climatology_1.0_01      netCDF
# 13     February, 1° spatial resolution  utrack_climatology_1.0_02      netCDF
# 14        March, 1° spatial resolution  utrack_climatology_1.0_03      netCDF
# 15        April, 1° spatial resolution  utrack_climatology_1.0_04      netCDF
# 16          May, 1° spatial resolution  utrack_climatology_1.0_05      netCDF
# 17         June, 1° spatial resolution  utrack_climatology_1.0_06      netCDF
# 18         July, 1° spatial resolution  utrack_climatology_1.0_07      netCDF
# 19       August, 1° spatial resolution  utrack_climatology_1.0_08      netCDF
# 20    September, 1° spatial resolution  utrack_climatology_1.0_09      netCDF
# 21      October, 1° spatial resolution  utrack_climatology_1.0_10      netCDF
# 22     November, 1° spatial resolution  utrack_climatology_1.0_11      netCDF
# 23     December, 1° spatial resolution  utrack_climatology_1.0_12      netCDF
#
#     File size [kByte]                                           URL file
# 0        1.029788e+07  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 1        1.027730e+07  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 2        9.748976e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 3        9.553866e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 4        9.616981e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 5        9.488671e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 6        9.669828e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 7        9.541763e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 8        9.436493e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 9        9.531932e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 10       9.171279e+06  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 11       1.014437e+07  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 12       9.410673e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 13       9.422363e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 14       9.093147e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 15       8.827687e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 16       8.890051e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 17       8.797984e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 18       8.915885e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 19       8.850023e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 20       8.697225e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 21       8.724481e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 22       8.515241e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...
# 23       9.327789e+05  https://hs.pangaea.de/Maps/Tuinenburg-etal_202...

# %%
import requests, os
from tqdm import tqdm     # só para barra de progresso

pasta = "utrack_nc"       # onde salvar
os.makedirs(pasta, exist_ok=True)

for url, nome in zip(df["URL file"], df["File name"]):
    destino = os.path.join(pasta, f"{nome}.nc")
    if os.path.exists(destino):
        print(f"😎 {destino} já existe, pulando.")
        continue
    print(f"⬇️  Baixando {destino}...")
    r = requests.get(url, stream=True, timeout=60)
    r.raise_for_status()
    total = int(r.headers.get("content-length", 0))
    with open(destino, "wb") as f, tqdm(
        total=total, unit="B", unit_scale=True, desc=nome
    ) as pbar:
        for chunk in r.iter_content(chunk_size=1024 * 1024):
            f.write(chunk)
            pbar.update(len(chunk))
# Out:
# ⬇️  Baixando utrack_nc/utrack_climatology_0.5_01.nc...
# utrack_climatology_0.5_01: 100%|██████████| 10.5G/10.5G [06:36<00:00, 26.6MB/s]
# ⬇️  Baixando utrack_nc/utrack_climatology_0.5_02.nc...
# utrack_climatology_0.5_02: 100%|██████████| 10.5G/10.5G [06:40<00:00, 26.2MB/s]
# ⬇️  Baixando utrack_nc/utrack_climatology_0.5_03.nc...
# utrack_climatology_0.5_03: 100%|██████████| 9.98G/9.98G [05:45<00:00, 28.9MB/s]
# ⬇️  Baixando utrack_nc/utrack_climatology_0.5_04.nc...
# utrack_climatology_0.5_04:   6%|▌         | 587M/9.78G [00:21<05:41, 26.9MB/s]
