# %% [markdown]
# ### lendo

# %%
import pandas as pd

path_energy = r'data_raw\Production, Trade and Supply of Energy.csv'
path_pib = r'data_raw\GDP and GDP Per Capita.csv'

df_energy = pd.read_csv(path_energy, sep = ',')
df_pib = pd.read_csv(path_pib, sep = ',')

# %%
df_energy
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2000
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2015
# ...                   ...                            ...   ...
# 8578                  716                       Zimbabwe  2010
# 8579                  716                       Zimbabwe  2015
# 8580                  716                       Zimbabwe  2019
# 8581                  716                       Zimbabwe  2020
# 8582                  716                       Zimbabwe  2021
#
#                                       Series    Value  Footnotes  \
# 0     Primary energy production (petajoules)  381,716        NaN
# 1     Primary energy production (petajoules)  412,282        NaN
# ...

# %%
df_pib
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2020
# ...                   ...                            ...   ...
# 6769                  716                       Zimbabwe  2010
# 6770                  716                       Zimbabwe  2015
# 6771                  716                       Zimbabwe  2020
# 6772                  716                       Zimbabwe  2021
# 6773                  716                       Zimbabwe  2022
#
#                                               Series       Value Footnotes  \
# 0     GDP in current prices (millions of US dollars)  31,290,901       NaN
# ...
